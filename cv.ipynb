# %%
import pandas as pd
import os

# 현재 파이썬 코드의 파일 경로
current_path = os.getcwd()  # 현재 작업 디렉토리를 가져옵니다.

# CSV 파일 경로
file_path = os.path.join(current_path, 'filtered_data.csv')  # User uploaded fioytle to this path

df = pd.read_csv(file_path)
df
# Out:
#         note id  person id  age gender source value        BMI  \
# 0        101058         29   81                   F  25.247087
# 1         57801         64   60                   F  24.376249
# 2         71288         64   60                   F  24.376249
# 3        135104         64   60                   F  24.376249
# 4        221210         71   94                   M  27.963140
# ...         ...        ...  ...                 ...        ...
# 161214   297111    4055249    1                   M  23.700428
# 161215   297455    4055328    1                   M  20.612160
# 161216   297761    4055407    1                   M  12.502703
# 161217   297753    4055558    4                   F  14.365794
# 161218   298112    4055685    1                   M  18.382103
#
#        admission department   division   ward  asa class  surgeon id  ...  \
# 0           General Surgery  Admission  NUGW2          2        9885  ...
# 1            Otolaryngology  Admission    102          2        6194  ...
# 2            Otolaryngology  Admission    102          3        6194  ...
# 3            Otolaryngology  Admission    102          3        6194  ...
# 4               Orthopedics  Admission     41          2       29473  ...
# ...                     ...        ...    ...        ...         ...  ...
# 161214    Pediatric Surgery  Admission     5A          1      100613  ...
# 161215    Pediatric Urology        Day   PDSC          1        6259  ...
# 161216    Pediatric Surgery  Admission     5A          2      105057  ...
# 161217    Pediatric Surgery  Admission     5A          2      105057  ...
# 161218    Pediatric Surgery  Admission     5A          1      105057  ...
#
#        condition source value surgery room previous surgery emergency status  \
# 0                   D00002196          203                N                N
# 1                   D00003798          504                N                N
# 2                   D00003798          504                Y                N
# 3                   D00003798          504                Y                N
# 4                   D00018711          108                N                N
# ...                       ...          ...              ...              ...
# 161214              D00011688            5                N                Y
# 161215              D00016707            7                N                N
# 161216              D00011524            5                N                N
# 161217              D00004831            5                N                N
# 161218              D00011589            5                N                N
#
#        op timing day of the week week of the month      month  \
# 0            TF2        Thursday                 4    October
# 1             8A          Friday                 2    January
# 2            TF4          Monday                 4      April
# 3            TF2          Monday                 3     August
# 4            TF4          Monday                 5      March
# ...          ...             ...               ...        ...
# 161214       etc         Tuesday                 2  September
# 161215        8A          Monday                 4  September
# 161216        8A       Wednesday                 3  September
# 161217       TF6       Wednesday                 3  September
# 161218        8A          Friday                 4  September
#
#        surgeon estimated op time surgery duration
# 0                            130               66
# 1                            300              130
# 2                            100               85
# 3                            100               83
# 4                            100               63
# ...                          ...              ...
# 161214                       200              123
# 161215                       130               45
# 161216                       130               43
# 161217                       130               82
# 161218                       130               75
#
# [161219 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split

# Removing unnecessary columns
df.drop(columns=['note id', 'person id', 'surgeon estimated op time', 'final op name'], inplace=True)

# Encoding binary columns
binary_cols = ['condition source value']
for col in binary_cols:
    df[col] = df[col].astype('category').cat.codes

# One-hot encoding for other categorical columns
one_hot_cols = ['surgical department', 'op timing', 'month', 'anesthesia type',
                'day of the week', 'asa class', 'week of the month', 
                'division', 'previous surgery', 'emergency status', 'gender source value', 'surgeon id', 'ward', 
                'admission department', 'surgery room', 'op code']
df_encoded = pd.get_dummies(df, columns=one_hot_cols)

# Splitting the data
X_all = df_encoded.drop("surgery duration", axis=1)
y_all = df_encoded["surgery duration"]
X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(X_all, y_all, test_size=0.2, random_state=42)

# Displaying the first few rows of the resulting dataframe
X_train_all
y_train_all
# Out:
# 61344     122
# 137241     48
# 139478     76
# 113549     36
# 149411    127
#          ...
# 119879     76
# 103694     57
# 131932    311
# 146867     82
# 121958     57
# Name: surgery duration, Length: 128975, dtype: int64

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

cross_val_scores_rf = {}

# Preparing department-specific datasets
departments = df['surgical department'].unique()
department_models = {}
predictions = {}


# Training models for each department
for dept in departments:
    # Adjusting column name
    dept_col_name = 'surgical department_' + dept

    # Filtering data for the department
    dept_data = df_encoded[df_encoded[dept_col_name] == 1]
    X_dept = dept_data.drop('surgery duration', axis=1)
    y_dept = dept_data['surgery duration'] 

    # Splitting the data
    X_train_dept, X_test_dept, y_train_dept, y_test_dept = train_test_split(X_dept, y_dept, test_size=0.2, random_state=42)

    # Training the model with cross-validation
    department_model = RandomForestRegressor(random_state=42)
    cv_scores_rf = cross_val_score(department_model, X_dept, y_dept, cv=5)
    cross_val_scores_rf[dept] = cv_scores_rf.mean()

    # Training and saving the final model
    department_model.fit(X_train_dept, y_train_dept)
    department_models[dept] = department_model

    # Making predictions on the test dataset
    predictions[dept] = department_model.predict(X_test_dept)


# Preparing for ensemble
final_predictions = np.zeros(len(X_test_all))
test_indices = X_test_all.index

# Applying each department-specific model to the entire test dataset
for dept, department_model in department_models.items():
    # Adjusting column name
    dept_col_name = 'surgical department_' + dept

    # Indices of test data belonging to the department
    dept_indices = X_test_all[X_test_all[dept_col_name] == 1].index

    # Calculating predictions for the department
    dept_predictions = department_model.predict(X_test_all.loc[dept_indices])

    # Updating the final prediction array
    final_predictions[np.isin(test_indices, dept_indices)] = dept_predictions

# Evaluating performance
mae_rf = mean_absolute_error(y_test_all, final_predictions)
rmse_rf = np.sqrt(mean_squared_error(y_test_all, final_predictions))
r2_rf = r2_score(y_test_all, final_predictions)

# The code is now updated with model names changed to 'department_model'
mae_rf, rmse_rf, r2_rf, cross_val_scores_rf
# Out:
# (16.31609725840466,
#  31.194884246574414,
#  0.9182941982331316,
#  {'General Surgery': 0.7050438983428752,
#   'Otolaryngology': 0.5120305877911308,
#   'Orthopedics': 0.5697064996987388,
#   'Ophthalmology': 0.5640180252022722,
#   'Obstetrics & Gynecology': 0.5723474866934856,
#   'Urology': 0.737185688762261,
#   'Plastic Surgery': 0.6641670412949365,
#   'Neurosurgery': 0.6032151485100539,
#   'Cardiovascular Thoracic Surgery': 0.7608410657977179,
#   'Pediatric Otolaryngology': 0.6078566170008582,
#   'Pediatric Orthopedics': 0.3689651287347432,
#   'Pediatric Thoracic Surgery': 0.7642918617017577,
#   'Pediatric Urology': 0.5425211264079169,
#   'Pediatric Surgery': 0.5275359403242167,
#   'Pediatric Ophthalmology': 0.4036646450428343,
#   'Pediatric Plastic Surgery': 0.4546544327812446,
#   'Pediatric Neurosurgery': 0.5525888713755711})

# %%
import matplotlib.pyplot as plt

# 부서별 교차 검증 점수를 바 차트로 표시
departments = list(cross_val_scores_rf.keys())
cv_scores_rf = [cross_val_scores_rf[dept] for dept in departments]

plt.figure(figsize=(10, 6))
plt.bar(departments, cv_scores_rf, color='skyblue')
plt.xlabel('Surgical Department')
plt.ylabel('Average Cross-Validation Score')
plt.title('Cross-Validation Scores by Department')
plt.xticks(rotation=45)
plt.show()

# %%
# Assuming the necessary imports and data preparation steps are already done
# Modifying the code to include department-wise performance metrics

# Variables to store department-wise performance metrics
department_wise_mae = {}
department_wise_rmse = {}
department_wise_r2 = {}

# Training models for each department and evaluating their performance
for dept in departments:
    # Adjusting column name and filtering data
    dept_col_name = 'surgical department_' + dept
    dept_data = df_encoded[df_encoded[dept_col_name] == 1]
    X_dept = dept_data.drop('surgery duration', axis=1)
    y_dept = dept_data['surgery duration']

    # Splitting the data
    X_train_dept, X_test_dept, y_train_dept, y_test_dept = train_test_split(X_dept, y_dept, test_size=0.2, random_state=42)

    # Training the RandomForest model
    department_model = RandomForestRegressor(random_state=42)
    department_model.fit(X_train_dept, y_train_dept)

    # Saving the trained model
    department_models[dept] = department_model

    # Making predictions on the test dataset and evaluating performance
    dept_predictions = department_model.predict(X_test_dept)
    mae = mean_absolute_error(y_test_dept, dept_predictions)
    rmse = np.sqrt(mean_squared_error(y_test_dept, dept_predictions))
    r2 = r2_score(y_test_dept, dept_predictions)

    # Storing the metrics for each department
    department_wise_mae[dept] = mae
    department_wise_rmse[dept] = rmse
    department_wise_r2[dept] = r2

# Display the metrics for each department
department_wise_mae, department_wise_rmse, department_wise_r2
# Out:
# ({'General Surgery': 35.51381409377571,
#   'Otolaryngology': 44.70250106157113,
#   'Orthopedics': 34.59686823104693,
#   'Ophthalmology': 12.906625573394495,
#   'Obstetrics & Gynecology': 34.69990008688097,
#   'Urology': 24.433103177716752,
#   'Plastic Surgery': 40.27894799054374,
#   'Neurosurgery': 49.64263560500695,
#   'Cardiovascular Thoracic Surgery': 48.85646869983949,
#   'Pediatric Otolaryngology': 22.325836947094533,
#   'Pediatric Orthopedics': 49.609154929577464,
#   'Pediatric Thoracic Surgery': 52.08353723404255,
#   'Pediatric Urology': 37.74042016806723,
#   'Pediatric Surgery': 30.774422360248447,
#   'Pediatric Ophthalmology': 10.321978371501272,
#   'Pediatric Plastic Surgery': 31.766917647058822,
#   'Pediatric Neurosurgery': 65.31850427350427},
#  {'General Surgery': 54.4762901369511,
#   'Otolaryngology': 75.64145919403012,
#   'Orthopedics': 61.00651899804417,
#   'Ophthalmology': 22.012938309328927,
#   'Obstetrics & Gynecology': 56.377456329927135,
#   'Urology': 39.868011240623275,
#   'Plastic Surgery': 73.87016599089553,
#   'Neurosurgery': 73.84109265674972,
#   'Cardiovascular Thoracic Surgery': 70.43907581528981,
#   'Pediatric Otolaryngology': 40.08447158637698,
#   'Pediatric Orthopedics': 76.28537862482835,
#   'Pediatric Thoracic Surgery': 75.687595738471,
#   'Pediatric Urology': 85.51488627694002,
#   'Pediatric Surgery': 57.53382247488367,
#   'Pediatric Ophthalmology': 14.248838444244432,
#   'Pediatric Plastic Surgery': 47.58914686453328,
#   'Pediatric Neurosurgery': 95.65326918830456},
#  {'General Surgery': 0.7188277020214531,
#   'Otolaryngology': 0.5338892253177067,
#   'Orthopedics': 0.572042117632332,
#   'Ophthalmology': 0.5954679679620969,
#   'Obstetrics & Gynecology': 0.574790976199564,
#   'Urology': 0.7412147855100308,
#   'Plastic Surgery': 0.6612756529189243,
#   'Neurosurgery': 0.6475118176772297,
#   'Cardiovascular Thoracic Surgery': 0.7694679768825574,
#   'Pediatric Otolaryngology': 0.6263804090273366,
#   'Pediatric Orthopedics': 0.3834275361507882,
#   'Pediatric Thoracic Surgery': 0.8232339583025694,
#   'Pediatric Urology': 0.4227700401319524,
#   'Pediatric Surgery': 0.48393710214006735,
#   'Pediatric Ophthalmology': 0.4756290258795659,
#   'Pediatric Plastic Surgery': 0.5330171058100991,
#   'Pediatric Neurosurgery': 0.6040377810507588})

# %%
# Training a model on the entire dataset

# RandomForest model
model_all = RandomForestRegressor(random_state=42)
model_all.fit(X_train_all, y_train_all)

# Making predictions on the test dataset
predictions_all = model_all.predict(X_test_all)

# Evaluating performance
mae_all = mean_absolute_error(y_test_all, predictions_all)
rmse_all = np.sqrt(mean_squared_error(y_test_all, predictions_all))
r2_all = r2_score(y_test_all, predictions_all)

# Performance metrics for the model trained on the entire dataset
mae_all, rmse_all, r2_all
# Out:
# (32.95421042157714, 56.3171938489969, 0.73370184792376)
